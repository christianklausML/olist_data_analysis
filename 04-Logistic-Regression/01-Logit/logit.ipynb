# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # `Logit` on Orders - A warm-up challenge (~1h)

# %% [markdown]
# ## Select features

# %% [markdown]
# 🎯 Let's figure out the impact of `wait_time` and `delay_vs_expected` on very `good/bad reviews`
#
# 👉 Using our `orders` training_set, we will run two `multivariate logistic regressions`:
# - `logit_one` to predict `dim_is_one_star`
# - `logit_five` to predict `dim_is_five_star`.

# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from scipy.stats import zscore
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

# %% [markdown]
# 👉 Import your dataset:

# %%
from olist.order import Order
orders = Order().get_training_data(with_distance_seller_customer=True)

# %% [markdown]
# 👉 Select in a list which features you want to use:
#
# ⚠️ Make sure you are not creating data leakage (i.e. selecting features that are derived from the target)
#
# 💡 To figure out the impact of `wait_time` and `delay_vs_expected` we need to control for the impact of other features, include in your list all features that may be relevant

# %%
def standardize(df, features):
    df_standardized = df.copy()
    for f in features:
        mu = df[f].mean()
        sigma = df[f].std()
        df_standardized[f] = df[f].map(lambda x: (x - mu) / sigma)
    return df_standardized

# %%
orders.head()
# Out:
#                            order_id  wait_time  expected_wait_time  \
# 0  e481f51cbdc54678b7cc49136f2d6af7   8.436574           15.544063
# 1  53cdb2fc8bc7dce0b6741e2150273451  13.782037           19.137766
# 2  47770eb9100c2d0c44946d9cf07ec65d   9.394213           26.639711
# 3  949d5b44dbf5de918fe9c16f97b45f8a  13.208750           26.188819
# 4  ad21c59c0840e6cb83a9ceb5573f8159   2.873877           12.112049
#
#    delay_vs_expected order_status  dim_is_five_star  dim_is_one_star  \
# 0                0.0    delivered                 0                0
# 1                0.0    delivered                 0                0
# 2                0.0    delivered                 1                0
# 3                0.0    delivered                 1                0
# 4                0.0    delivered                 1                0
#
#    review_score  number_of_products  number_of_sellers   price  freight_value  \
# 0             4                   1                  1   29.99           8.72
# 1             4                   1                  1  118.70          22.76
# 2             5                   1                  1  159.90          19.22
# 3             5                   1                  1   45.00          27.20
# 4             5                   1                  1   19.90           8.72
#
#    distance_seller_customer
# 0                 18.063837
# 1                856.292580
# 2                514.130333
# 3               1822.800366
# 4                 30.174037

# %%
features = ['wait_time','delay_vs_expected','price','number_of_sellers',
            'distance_seller_customer', 'number_of_products']

# %% [markdown]
# 🕵🏻 Check the `multi-colinearity` of your features, using the `VIF index`.
#
# * It shouldn't be too high (< 10 preferably) to ensure that we can trust the partial regression coefficents and their associated `p-values`
# * Do not forget to standardize your data !
#     * A `VIF Analysis` is made by regressing a feature vs. the other features...
#     * So you want to `remove the effect of scale` so that your features have an equal importance before running any linear regression!
#
#
# 📚 <a href="https://www.statisticshowto.com/variance-inflation-factor/">Statistics How To - Variance Inflation Factor</a>
#
# 📚  <a href="https://online.stat.psu.edu/stat462/node/180/">PennState - Detecting Multicollinearity Using Variance Inflation Factors</a>

# %% [markdown]
# ⚖️ Standardizing:

# %%
orders_standardized = standardize(orders, features)
orders_standardized
# Out:
#                                order_id  wait_time  expected_wait_time  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  -0.431192           15.544063
# 1      53cdb2fc8bc7dce0b6741e2150273451   0.134174           19.137766
# 2      47770eb9100c2d0c44946d9cf07ec65d  -0.329907           26.639711
# 3      949d5b44dbf5de918fe9c16f97b45f8a   0.073540           26.188819
# 4      ad21c59c0840e6cb83a9ceb5573f8159  -1.019535           12.112049
# ...                                 ...        ...                 ...
# 95875  9c5dedf39a927c1b2549525ed64a053c  -0.454309           18.587442
# 95876  63943bddc261676b46f01ca7ac2f7bd8   1.023841           23.459051
# 95877  83c1379a015df1e13d02aae0204711ab   1.305780           30.384225
# 95878  11c177c8e97725db2631073c19f07b62   0.483664           37.105243
# 95879  66dea50a8b16d9b4dee7af250b4be1a5  -0.511814           25.126736
#
#        delay_vs_expected order_status  dim_is_five_star  dim_is_one_star  \
# 0              -0.161781    delivered                 0                0
# 1              -0.161781    delivered                 0                0
# 2              -0.161781    delivered                 1                0
# 3              -0.161781    delivered                 1                0
# 4              -0.161781    delivered                 1                0
# ...                  ...          ...               ...              ...
# 95875          -0.161781    delivered                 1                0
# 95876          -0.161781    delivered                 0                0
# 95877          -0.161781    delivered                 1                0
# 95878          -0.161781    delivered                 0                0
# 95879          -0.161781    delivered                 1                0
#
#        review_score  number_of_products  number_of_sellers     price  \
# 0                 4           -0.264595          -0.112544 -0.513802
# 1                 4           -0.264595          -0.112544 -0.086640
# 2                 5           -0.264595          -0.112544  0.111748
# 3                 5           -0.264595          -0.112544 -0.441525
# 4                 5           -0.264595          -0.112544 -0.562388
# ...             ...                 ...                ...       ...
# 95875             5           -0.264595          -0.112544 -0.311513
# 95876             4           -0.264595          -0.112544  0.183977
# 95877             5           -0.264595          -0.112544  0.333684
# 95878             2            1.601605          -0.112544  1.075186
# 95879             5           -0.264595          -0.112544 -0.328367
#
#        freight_value  distance_seller_customer
# 0          -0.652038                 -0.979475
# 1           0.000467                  0.429743
# 2          -0.164053                 -0.145495
# 3           0.206815                  2.054621
# 4          -0.652038                 -0.959115
# ...              ...                       ...
# 95875      -0.449408                 -0.893033
# 95876      -0.123156                 -0.212797
# 95877       1.964490                  0.617630
# 95878       2.715522                 -0.387558
# 95879      -0.204022                  0.052359
#
# [95872 rows x 13 columns]

# %% [markdown]
# 👉 Run your VIF Analysis to analyze the potential multicolinearities:

# %%
# Correlation matix is not sufficient to detect soft or event strict multicolinearity
orders_standardized.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5a8da_row0_col0, #T_5a8da_row1_col1, #T_5a8da_row2_col2, #T_5a8da_row3_col3, #T_5a8da_row4_col4, #T_5a8da_row5_col5, #T_5a8da_row6_col6, #T_5a8da_row7_col7, #T_5a8da_row8_col8, #T_5a8da_row9_col9, #T_5a8da_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5a8da_row0_col1, #T_5a8da_row1_col5, #T_5a8da_row10_col5 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_5a8da_row0_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_5a8da_row0_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_5a8da_row0_col4 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_5a8da_row0_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_5a8da_row0_col6, #T_5a8da_row3_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_5a8da_row0_col7 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_5a8da_row0_col8, #T_5a8da_row2_col7 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_5a8da_row0_col9, #T_5a8da_row6_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_5a8da_row0_col10, #T_5a8da_row8_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_5a8da_row1_col0, #T_5a8da_row1_col10 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_5a8da_row1_col2, #T_5a8da_row4_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_5a8da_row1_col3, #T_5a8da_row8_col6 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_5a8da_row1_col4 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_5a8da_row1_col6, #T_5a8da_row8_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_5a8da_row1_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_5a8da_row1_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_5a8da_row1_col9 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_5a8da_row2_col0 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_5a8da_row2_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_5a8da_row2_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_5a8da_row2_col4 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_5a8da_row2_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_5a8da_row2_col6, #T_5a8da_row4_col10, #T_5a8da_row10_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_5a8da_row2_col8, #T_5a8da_row7_col10 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_5a8da_row2_col9 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_5a8da_row2_col10 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_5a8da_row3_col0, #T_5a8da_row4_col8, #T_5a8da_row7_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_5a8da_row3_col1, #T_5a8da_row3_col10, #T_5a8da_row4_col3, #T_5a8da_row4_col5, #T_5a8da_row5_col0, #T_5a8da_row5_col1, #T_5a8da_row5_col2, #T_5a8da_row5_col4, #T_5a8da_row5_col6, #T_5a8da_row5_col7, #T_5a8da_row5_col8, #T_5a8da_row5_col9, #T_5a8da_row5_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5a8da_row3_col4, #T_5a8da_row8_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_5a8da_row3_col5 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_5a8da_row3_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_5a8da_row3_col7, #T_5a8da_row6_col10 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_5a8da_row3_col8 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_5a8da_row3_col9 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_5a8da_row4_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_5a8da_row4_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_5a8da_row4_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_5a8da_row4_col7 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_5a8da_row4_col9 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_5a8da_row5_col3 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_5a8da_row6_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_5a8da_row6_col2, #T_5a8da_row7_col9 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_5a8da_row6_col3, #T_5a8da_row7_col3, #T_5a8da_row9_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_5a8da_row6_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_5a8da_row6_col5, #T_5a8da_row9_col0 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_5a8da_row6_col7 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_5a8da_row6_col8 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_5a8da_row6_col9 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_5a8da_row7_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_5a8da_row7_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_5a8da_row7_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_5a8da_row7_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_5a8da_row7_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_5a8da_row7_col6 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_5a8da_row8_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_5a8da_row8_col3, #T_5a8da_row9_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_5a8da_row8_col4, #T_5a8da_row10_col4 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_5a8da_row8_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_5a8da_row8_col9 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_5a8da_row8_col10 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_5a8da_row9_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_5a8da_row9_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_5a8da_row9_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_5a8da_row9_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_5a8da_row9_col7 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_5a8da_row9_col8 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_5a8da_row9_col10 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_5a8da_row10_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_5a8da_row10_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_5a8da_row10_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_5a8da_row10_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_5a8da_row10_col7 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_5a8da_row10_col8 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_5a8da_row10_col9 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# </style>
# <table id="T_5a8da_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >wait_time</th>
#       <th class="col_heading level0 col1" >expected_wait_time</th>
#       <th class="col_heading level0 col2" >delay_vs_expected</th>
#       <th class="col_heading level0 col3" >dim_is_five_star</th>
#       <th class="col_heading level0 col4" >dim_is_one_star</th>
#       <th class="col_heading level0 col5" >review_score</th>
#       <th class="col_heading level0 col6" >number_of_products</th>
#       <th class="col_heading level0 col7" >number_of_sellers</th>
#       <th class="col_heading level0 col8" >price</th>
#       <th class="col_heading level0 col9" >freight_value</th>
#       <th class="col_heading level0 col10" >distance_seller_customer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a8da_level0_row0" class="row_heading level0 row0" >wait_time</th>
#       <td id="T_5a8da_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5a8da_row0_col1" class="data row0 col1" >0.385628</td>
#       <td id="T_5a8da_row0_col2" class="data row0 col2" >0.702597</td>
#       <td id="T_5a8da_row0_col3" class="data row0 col3" >-0.234101</td>
#       <td id="T_5a8da_row0_col4" class="data row0 col4" >0.305577</td>
#       <td id="T_5a8da_row0_col5" class="data row0 col5" >-0.334036</td>
#       <td id="T_5a8da_row0_col6" class="data row0 col6" >-0.019754</td>
#       <td id="T_5a8da_row0_col7" class="data row0 col7" >-0.040702</td>
#       <td id="T_5a8da_row0_col8" class="data row0 col8" >0.055638</td>
#       <td id="T_5a8da_row0_col9" class="data row0 col9" >0.167284</td>
#       <td id="T_5a8da_row0_col10" class="data row0 col10" >0.394984</td>
#     </tr>
#     <tr>
#       <

# %%
orders_features = orders_standardized[features]

df = pd.DataFrame()

df["features"] = orders_features.columns

df["vif_index"] = [vif(orders_features.values, i) for i in range(orders_features.shape[1])]

round(df.sort_values(by="vif_index", ascending = False),2)
# Out:
#                    features  vif_index
# 0                 wait_time       2.62
# 1         delay_vs_expected       2.21
# 4             freight_value       1.67
# 5  distance_seller_customer       1.44
# 6        number_of_products       1.37
# 2                     price       1.21
# 3         number_of_sellers       1.09

# %% [markdown]
# ## Logistic Regressions

# %% [markdown]
# 👉 Fit two `Logistic Regression` models:
# - `logit_one` to predict `dim_is_one_star`
# - `logit_five` to predict `dim_is_five_star`.

# %% [markdown]
# `Logit 1️⃣`

# %%
logit_one = smf.logit(formula=f"dim_is_one_star ~ {' + '.join(features)}", data=orders_standardized).fit();
logit_one.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.273598
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        dim_is_one_star   No. Observations:                95872
# Model:                          Logit   Df Residuals:                    95865
# Method:                           MLE   Df Model:                            6
# Date:                Tue, 22 Feb 2022   Pseudo R-squ.:                  0.1447
# Time:                        19:48:20   Log-Likelihood:                -26230.
# converged:                       True   LL-Null:                       -30669.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -2.4673      0.013   -190.880      0.000      -2.493      -2.442
# wait_time                    0.7101      0.017     42.178      0.000       0.677       0.743
# delay_vs_expected            0.2570      0.018     13.910      0.000       0.221       0.293
# price                        0.0431      0.010      4.105      0.000       0.023       0.064
# number_of_sellers            0.1776      0.008     22.621      0.000       0.162       0.193
# distance_seller_customer    -0.1844      0.013    -13.787      0.000      -0.211      -0.158
# number_of_products           0.2409      0.009     26.272      0.000       0.223       0.259
# ============================================================================================
# """

# %% [markdown]
# `Logit 5️⃣`

# %%
logit_five = smf.logit(formula=f"dim_is_five_star ~ {' + '.join(features)}", data=orders_standardized).fit();
logit_five.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.636832
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       dim_is_five_star   No. Observations:                95872
# Model:                          Logit   Df Residuals:                    95865
# Method:                           MLE   Df Model:                            6
# Date:                Tue, 22 Feb 2022   Pseudo R-squ.:                 0.05805
# Time:                        19:48:41   Log-Likelihood:                -61054.
# converged:                       True   LL-Null:                       -64817.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.3388      0.007     47.337      0.000       0.325       0.353
# wait_time                   -0.5214      0.012    -44.772      0.000      -0.544      -0.499
# delay_vs_expected           -0.4335      0.024    -18.442      0.000      -0.480      -0.387
# price                        0.0225      0.007      3.180      0.001       0.009       0.036
# number_of_sellers           -0.1426      0.008    -18.212      0.000      -0.158      -0.127
# distance_seller_customer     0.0886      0.008     11.126      0.000       0.073       0.104
# number_of_products          -0.1344      0.008    -17.742      0.000      -0.149      -0.120
# ============================================================================================
# """

# %% [markdown]
# 💡 It's time to analyse the results of these two logistic regressions:
#
# - Interpret the partial coefficients in your own words.
# - Check their statistical significances with `p-values`
# - Do you notice any differences between `logit_one` and `logit_five` in terms of coefficient importances?

# %%
# Among the following sentences, store the ones that are true in the list below

a = "delay_vs_expected influences five_star ratings even more than one_star ratings"
b = "wait_time influences five_star ratings even more more than one_star"

your_answer = [a]

# %% [markdown]
# 🧪 __Test your code__

# %%
from nbresult import ChallengeResult

result = ChallengeResult('logit',
    answers = your_answer
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /Users/christianklaus/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/christianklaus/code/christianklausML/data-challenges/04-Decision-Science/04-Logistic-Regression/01-Logit
# plugins: anyio-3.4.0
# collecting ... collected 1 item
#
# tests/test_logit.py::TestLogit::test_question PASSED                     [100%]
#
# ============================== 1 passed in 0.04s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/logit.pickle
#
# git commit -m 'Completed logit step'
#
# git push origin master

# %% [markdown]
# <details>
#     <summary>- <i>Explanations and advanced concepts </i> -</summary>
#
#
# > _All other thing being equal, the `delay factor` tends to increase the chances of getting stripped of the 5-star even more so than it affect the chances of 1-star reviews. Probably because 1-stars are really targeting bad products themselves, not bad deliveries_
#
# ❗️ However, to be totally rigorous, we have to be **more careful when comparing coefficients from two different models**, because **they might not be based on similar populations**!
#     We have 2 sub-populations here: (people who gave 1-stars; and people who gave 5-stars) and they may exhibit intrinsically different behavior patterns. It may well be that "happy-people" (who tends to give 5-stars easily) are less sensitive as "grumpy-people" (who shoot 1-stars like Lucky-Luke), when it comes to "delay", or "price"...
#
# </details>

# %% [markdown]
# ## Logistic vs. Linear ?

# %% [markdown]
# 👉 Compare:
# - the regression coefficients obtained from the `Logistic Regression `
# - with the regression coefficients obtained through a `Linear Regression`
# - on `review_score`, using the same features.
#
# ⚠️ Check that both sets of coefficients  tell  "the same story".

# %% [markdown]
# > more or less same, except for price

# %%
# YOUR CODE HERE

# %% [markdown]
# 🏁 Congratulations!
#
# 💾 Don't forget to commit and push your `logit.ipynb` notebook !
